-- %%
select 
tournament_name,
year,
start_date,
end_date,
total_goals,
qualified_team,
total_matches,
final_attendance,
round(final_attendance/total_matches,0) avg_attendance_per_match,
host_country,
winner,
runners_up,
third,
fourth

 from fifa_bi_dev.gold_schema.dim_tournament
 order by year
